# %%
from keras.utils import to_categorical
from keras_preprocessing.image import load_img
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
import os
import pandas as pd
import numpy as np

# %%
TRAIN_DIR = 'images/train'
TEST_DIR = 'images/validation'

# %%
def createdataframe(dir):
    image_paths = []
    labels = []
    for label in os.listdir(dir):
        for imagename in os.listdir(os.path.join(dir,label)):
            image_paths.append(os.path.join(dir,label,imagename))
            labels.append(label)
        print(label, "completed")
    return image_paths,labels

# %%
train = pd.DataFrame()
train['image'], train['label'] = createdataframe(TRAIN_DIR)
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed

# %%
print(train)
# Out:
#                                 image     label
# 0            images/train\angry\0.jpg     angry
# 1            images/train\angry\1.jpg     angry
# 2           images/train\angry\10.jpg     angry
# 3        images/train\angry\10002.jpg     angry
# 4        images/train\angry\10016.jpg     angry
# ...                               ...       ...
# 28816  images/train\surprise\9969.jpg  surprise
# 28817  images/train\surprise\9985.jpg  surprise
# 28818  images/train\surprise\9990.jpg  surprise
# 28819  images/train\surprise\9992.jpg  surprise
# 28820  images/train\surprise\9996.jpg  surprise
#
# [28821 rows x 2 columns]

# %%
test = pd.DataFrame()
test['image'], test['label'] = createdataframe(TEST_DIR)
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed

# %%
print(test)
print(test['image'])
# Out:
#                                     image     label
# 0       images/validation\angry\10052.jpg     angry
# 1       images/validation\angry\10065.jpg     angry
# 2       images/validation\angry\10079.jpg     angry
# 3       images/validation\angry\10095.jpg     angry
# 4       images/validation\angry\10121.jpg     angry
# ...                                   ...       ...
# 7061  images/validation\surprise\9806.jpg  surprise
# 7062  images/validation\surprise\9830.jpg  surprise
# 7063  images/validation\surprise\9853.jpg  surprise
# 7064  images/validation\surprise\9878.jpg  surprise
# 7065   images/validation\surprise\993.jpg  surprise
#
# [7066 rows x 2 columns]
# 0         images/validation\angry\10052.jpg
# 1         images/validation\angry\10065.jpg
# 2         images/validation\angry\10079.jpg
# 3         images/validation\angry\10095.jpg
# 4         images/validation\angry\10121.jpg
#                        ...
# 7061    images/validation\surprise\9806.jpg
# 7062    images/validation\surprise\9830.jpg
# 7063    images/validation\surprise\9853.jpg
# 7064    images/validation\surprise\9878.jpg
# 7065     images/validation\surprise\993.jpg
# Name: image, Length: 7066, dtype: object

# %%
from tqdm.notebook import tqdm

# %%
def extract_features(images):
    features = []
    for image in tqdm(images):
        img = load_img(image,grayscale =  True )
        img = np.array(img)
        features.append(img)
    features = np.array(features)
    features = features.reshape(len(features),48,48,1)
    return features

# %%
train_features = extract_features(train['image'])
# Out:
#   0%|          | 0/28821 [00:00<?, ?it/s]
# C:\Users\hp\AppData\Local\Programs\Python\Python39\lib\site-packages\keras_preprocessing\image\utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
test_features = extract_features(test['image'])
# Out:
#   0%|          | 0/7066 [00:00<?, ?it/s]

# %%
x_train = train_features/255.0
x_test = test_features/255.0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le.fit(train['label'])
# Out:
# LabelEncoder()

# %%
y_train = le.transform(train['label'])
y_test = le.transform(test['label'])

# %%
y_train = to_categorical(y_train,num_classes = 7)
y_test = to_categorical(y_test,num_classes = 7)

# %%
model = Sequential()
# convolutional layers
model.add(Conv2D(128, kernel_size=(3,3), activation='relu', input_shape=(48,48,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(256, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Flatten())
# fully connected layers
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
# output layer
model.add(Dense(7, activation='softmax'))

# %%
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'] )

# %%
model.fit(x= x_train,y = y_train, batch_size = 128, epochs = 100, validation_data = (x_test,y_test))
# Out:
# Epoch 1/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 376s 2s/step - accuracy: 0.2328 - loss: 1.8393 - val_accuracy: 0.2583 - val_loss: 1.8093
# Epoch 2/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 374s 2s/step - accuracy: 0.2526 - loss: 1.8117 - val_accuracy: 0.2583 - val_loss: 1.8023
# Epoch 3/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 358s 2s/step - accuracy: 0.2619 - loss: 1.7854 - val_accuracy: 0.3218 - val_loss: 1.6901
# Epoch 4/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 418s 2s/step - accuracy: 0.3252 - loss: 1.6977 - val_accuracy: 0.3927 - val_loss: 1.5385
# Epoch 5/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 351s 2s/step - accuracy: 0.3774 - loss: 1.5871 - val_accuracy: 0.4496 - val_loss: 1.4329
# Epoch 6/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 393s 2s/step - accuracy: 0.4149 - loss: 1.5051 - val_accuracy: 0.4628 - val_loss: 1.3963
# Epoch 7/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 368s 2s/step - accuracy: 0.4385 - loss: 1.4448 - val_accuracy: 0.4887 - val_loss: 1.3222
# Epoch 8/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 371s 2s/step - accuracy: 0.4586 - loss: 1.4053 - val_accuracy: 0.5086 - val_loss: 1.3053
# Epoch 9/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 343s 2s/step - accuracy: 0.4690 - loss: 1.3750 - val_accuracy: 0.5231 - val_loss: 1.2570
# Epoch 10/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 358s 2s/step - accuracy: 0.4826 - loss: 1.3470 - val_accuracy: 0.5335 - val_loss: 1.2300
# Epoch 11/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 371s 2s/step - accuracy: 0.4970 - loss: 1.3161 - val_accuracy: 0.5330 - val_loss: 1.2173
# Epoch 12/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 363s 1s/step - accuracy: 0.5045 - loss: 1.3050 - val_accuracy: 0.5536 - val_loss: 1.1888
# Epoch 13/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 360s 2s/step - accuracy: 0.5145 - loss: 1.2763 - val_accuracy: 0.5515 - val_loss: 1.1816
# Epoch 14/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 358s 2s/step - accuracy: 0.5248 - loss: 1.2588 - val_accuracy: 0.5558 - val_loss: 1.1697
# Epoch 15/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 365s 2s/step - accuracy: 0.5244 - loss: 1.2540 - val_accuracy: 0.5628 - val_loss: 1.1574
# Epoch 16/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 384s 2s/step - accuracy: 0.5231 - loss: 1.2510 - val_accuracy: 0.5657 - val_loss: 1.1588
# Epoch 17/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 374s 2s/step - accuracy: 0.5341 - loss: 1.2254 - val_accuracy: 0.5626 - val_loss: 1.1509
# Epoch 18/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 370s 2s/step - accuracy: 0.5402 - loss: 1.2159 - val_accuracy: 0.5732 - val_loss: 1.1398
# Epoch 19/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 389s 2s/step - accuracy: 0.5457 - loss: 1.2109 - val_accuracy: 0.5805 - val_loss: 1.1295
# Epoch 20/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 353s 2s/step - accuracy: 0.5374 - loss: 1.2050 - val_accuracy: 0.5750 - val_loss: 1.1198
# Epoch 21/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 370s 2s/step - accuracy: 0.5453 - loss: 1.2001 - val_accuracy: 0.5780 - val_loss: 1.1231
# Epoch 22/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 371s 2s/step - accuracy: 0.5517 - loss: 1.1743 - val_accuracy: 0.5859 - val_loss: 1.1134
# Epoch 23/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 329s 1s/step - accuracy: 0.5508 - loss: 1.1781 - val_accuracy: 0.5841 - val_loss: 1.1102
# Epoch 24/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 330s 1s/step - accuracy: 0.5589 - loss: 1.1673 - val_accuracy: 0.5869 - val_loss: 1.1077
# Epoch 25/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 358s 2s/step - accuracy: 0.5539 - loss: 1.1658 - val_accuracy: 0.5836 - val_loss: 1.0996
# Epoch 26/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 346s 2s/step - accuracy: 0.5663 - loss: 1.1379 - val_accuracy: 0.5843 - val_loss: 1.1003
# Epoch 27/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 337s 1s/step - accuracy: 0.5708 - loss: 1.1364 - val_accuracy: 0.5923 - val_loss: 1.0930
# Epoch 28/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 337s 1s/step - accuracy: 0.5711 - loss: 1.1281 - val_accuracy: 0.5910 - val_loss: 1.0866
# Epoch 29/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 337s 1s/step - accuracy: 0.5704 - loss: 1.1325 - val_accuracy: 0.5974 - val_loss: 1.0812
# Epoch 30/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 424s 2s/step - accuracy: 0.5790 - loss: 1.1187 - val_accuracy: 0.5913 - val_loss: 1.0857
# Epoch 31/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 339s 1s/step - accuracy: 0.5796 - loss: 1.1098 - val_accuracy: 0.5972 - val_loss: 1.0841
# Epoch 32/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 338s 1s/step - accuracy: 0.5790 - loss: 1.1035 - val_accuracy: 0.5969 - val_loss: 1.0753
# Epoch 33/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 348s 2s/step - accuracy: 0.5883 - loss: 1.0925 - val_accuracy: 0.5900 - val_loss: 1.0962
# Epoch 34/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 358s 2s/step - accuracy: 0.5879 - loss: 1.0933 - val_accuracy: 0.6010 - val_loss: 1.0761
# Epoch 35/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 382s 2s/step - accuracy: 0.5861 - loss: 1.0904 - val_accuracy: 0.5944 - val_loss: 1.0752
# Epoch 36/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 349s 2s/step - accuracy: 0.5953 - loss: 1.0720 - val_accuracy: 0.5965 - val_loss: 1.0730
# Epoch 37/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 351s 2s/step - accuracy: 0.5925 - loss: 1.0743 - val_accuracy: 0.6019 - val_loss: 1.0742
# Epoch 38/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 384s 2s/step - accuracy: 0.5986 - loss: 1.0592 - val_accuracy: 0.6037 - val_loss: 1.0672
# Epoch 39/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 384s 2s/step - accuracy: 0.6024 - loss: 1.0542 - val_accuracy: 0.6052 - val_loss: 1.0528
# Epoch 40/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 381s 2s/step - accuracy: 0.6090 - loss: 1.0535 - val_accuracy: 0.6023 - val_loss: 1.0701
# Epoch 41/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 351s 2s/step - accuracy: 0.6082 - loss: 1.0421 - val_accuracy: 0.6052 - val_loss: 1.0657
# Epoch 42/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 343s 2s/step - accuracy: 0.6170 - loss: 1.0206 - val_accuracy: 0.6107 - val_loss: 1.0560
# Epoch 43/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 385s 2s/step - accuracy: 0.6030 - loss: 1.0383 - val_accuracy: 0.6018 - val_loss: 1.0621
# Epoch 44/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 336s 1s/step - accuracy: 0.6122 - loss: 1.0303 - val_accuracy: 0.6114 - val_loss: 1.0618
# Epoch 45/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 330s 1s/step - accuracy: 0.6102 - loss: 1.0303 - val_accuracy: 0.6012 - val_loss: 1.0732
# Epoch 46/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 403s 2s/step - accuracy: 0.6175 - loss: 1.0151 - val_accuracy: 0.6093 - val_loss: 1.0604
# Epoch 47/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 351s 2s/step - accuracy: 0.6203 - loss: 1.0135 - val_accuracy: 0.6063 - val_loss: 1.0601
# Epoch 48/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 351s 2s/step - accuracy: 0.6229 - loss: 1.0073 - val_accuracy: 0.6145 - val_loss: 1.0496
# Epoch 49/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 342s 2s/step - accuracy: 0.6218 - loss: 1.0006 - val_accuracy: 0.6146 - val_loss: 1.0451
# Epoch 50/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 327s 1s/step - accuracy: 0.6223 - loss: 1.0008 - val_accuracy: 0.6193 - val_loss: 1.0389
# Epoch 51/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 346s 2s/step - accuracy: 0.6296 - loss: 0.9905 - val_accuracy: 0.6160 - val_loss: 1.0521
# Epoch 52/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 383s 2s/step - accuracy: 0.6280 - loss: 0.9852 - val_accuracy: 0.6138 - val_loss: 1.0408
# Epoch 53/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 382s 2s/step - accuracy: 0.6317 - loss: 0.9751 - val_accuracy: 0.6118 - val_loss: 1.0473
# Epoch 54/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 317s 1s/step - accuracy: 0.6365 - loss: 0.9780 - val_accuracy: 0.6119 - val_loss: 1.0489
# Epoch 55/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 318s 1s/step - accuracy: 0.6273 - loss: 0.9926 - val_accuracy: 0.6136 - val_loss: 1.0423
# Epoch 56/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 341s 1s/step - accuracy: 0.6414 - loss: 0.9646 - val_accuracy: 0.6207 - val_loss: 1.0317
# Epoch 57/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 322s 1s/step - accuracy: 0.6372 - loss: 0.9610 - val_accuracy: 0.6138 - val_loss: 1.0451
# Epoch 58/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 324s 1s/step - accuracy: 0.6403 - loss: 0.9605 - val_accuracy: 0.6265 - val_loss: 1.0328
# Epoch 59/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 326s 1s/step - accuracy: 0.6376 - loss: 0.9604 - val_accuracy: 0.6179 - val_loss: 1.0355
# Epoch 60/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 327s 1s/step - accuracy: 0.6509 - loss: 0.9418 - val_accuracy: 0.6220 - val_loss: 1.0375
# Epoch 61/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 335s 1s/step - accuracy: 0.6452 - loss: 0.9565 - val_accuracy: 0.6194 - val_loss: 1.0411
# Epoch 62/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 367s 1s/step - accuracy: 0.6528 - loss: 0.9355 - val_accuracy: 0.6241 - val_loss: 1.0325
# Epoch 63/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 326s 1s/step - accuracy: 0.6571 - loss: 0.9286 - val_accuracy: 0.6180 - val_loss: 1.0395
# Epoch 64/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 328s 1s/step - accuracy: 0.6550 - loss: 0.9372 - val_accuracy: 0.6227 - val_loss: 1.0344
# Epoch 65/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 414s 2s/step - accuracy: 0.6594 - loss: 0.9174 - val_accuracy: 0.6194 - val_loss: 1.0380
# Epoch 66/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 355s 2s/step - accuracy: 0.6545 - loss: 0.9162 - val_accuracy: 0.6235 - val_loss: 1.0275
# Epoch 67/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 328s 1s/step - accuracy: 0.6623 - loss: 0.9017 - val_accuracy: 0.6240 - val_loss: 1.0241
# Epoch 68/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 385s 1s/step - accuracy: 0.6641 - loss: 0.9029 - val_accuracy: 0.6194 - val_loss: 1.0327
# Epoch 69/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 383s 1s/step - accuracy: 0.6616 - loss: 0.9144 - val_accuracy: 0.6166 - val_loss: 1.0415
# Epoch 70/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 335s 1s/step - accuracy: 0.6671 - loss: 0.8992 - val_accuracy: 0.6186 - val_loss: 1.0315
# Epoch 71/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 326s 1s/step - accuracy: 0.6749 - loss: 0.8788 - val_accuracy: 0.6254 - val_loss: 1.0235
# Epoch 72/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 392s 1s/step - accuracy: 0.6683 - loss: 0.8977 - val_accuracy: 0.6264 - val_loss: 1.0303
# Epoch 73/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 373s 1s/step - accuracy: 0.6762 - loss: 0.8770 - val_accuracy: 0.6211 - val_loss: 1.0236
# Epoch 74/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 378s 1s/step - accuracy: 0.6698 - loss: 0.8826 - val_accuracy: 0.6231 - val_loss: 1.0306
# Epoch 75/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 326s 1s/step - accuracy: 0.6743 - loss: 0.8776 - val_accuracy: 0.6214 - val_loss: 1.0342
# Epoch 76/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 318s 1s/step - accuracy: 0.6786 - loss: 0.8705 - val_accuracy: 0.6221 - val_loss: 1.0326
# Epoch 77/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 344s 2s/step - accuracy: 0.6839 - loss: 0.8609 - val_accuracy: 0.6224 - val_loss: 1.0307
# Epoch 78/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 406s 2s/step - accuracy: 0.6831 - loss: 0.8611 - val_accuracy: 0.6252 - val_loss: 1.0275
# Epoch 79/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 model.fit(x= x_train,y = y_train, batch_size = 128, epochs = 100, validation_data = (x_test,y_test))
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\backend\tensorflow\trainer.py:317, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     315 with epoch_iterator.catch_stop_iteration():
#     316     for step, iterator in epoch_iterator.enumerate_epoch():
# --> 317         callbacks.on_train_batch_begin(step)
#     318         logs = self.train_function(iterator)
#     319         logs = self._pythonify_logs(logs)
#
# KeyboardInterrupt:

# %%
model_json = model.to_json()
with open("emotiondetector.json",'w') as json_file:
    json_file.write(model_json)
model.save("emotiondetector.keras")

# %%
from keras.models import model_from_json

# %%
json_file = open("emotiondetector.json", "r")
model_json = json_file.read()
json_file.close()
model = model_from_json(model_json)
model.load_weights("emotiondetector.h5")

# %%
label = ['angry','disgust','fear','happy','neutral','sad','surprise']

# %%
def ef(image):
    img = load_img(image,grayscale =  True )
    feature = np.array(img)
    feature = feature.reshape(1,48,48,1)
    return feature/255.0

# %%
image = 'images/train/sad/42.jpg'
print("original image is of sad")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
# Out:
# original image is of sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# model prediction is  sad

# %%
image = 'images/train/disgust/299.jpg'
print("original image is of disgust")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
# Out:
# original image is of disgust
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# model prediction is  disgust

# %%
image = 'images/train/happy/7.jpg'
print("original image is of happy")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
# Out:
# original image is of happy
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 image = 'images/train/happy/7.jpg'
#       2 print("original image is of happy")
# ----> 3 img = ef(image)
#       4 pred = model.predict(img)
#       5 pred_label = label[pred.argmax()]
#
# NameError: name 'ef' is not defined

# %%
image = 'images/train/surprise/15.jpg'
print("original image is of surprise")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
# Out:
# original image is of surprise
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 image = 'images/train/surprise/15.jpg'
#       2 print("original image is of surprise")
# ----> 3 img = ef(image)
#       4 pred = model.predict(img)
#       5 pred_label = label[pred.argmax()]
#
# NameError: name 'ef' is not defined
